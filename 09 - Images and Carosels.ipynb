-- %% [markdown]
-- <div style="display: flex; justify-content: space-between; align-items: center; padding: 8px 16px; background: #F8F9FA; border-bottom: 2px solid #E0E0E0; margin: 0; line-height: 1;">
--     <div style="font-size: 14px; color: #666;">
--         <span style="font-weight: bold; color: #333;">Sandbox Magic</span>
--         <span style="margin-left: 8px; color: #999;">|</span>
--         <span style="margin-left: 8px;">Images and Carosels</span>
--     </div>
--     <div style="display: flex; align-items: center; gap: 8px;">
--         <img src="https://cdn.simpleicons.org/databricks/FF3621" width="24" height="24"/>
--     </div>
-- </div>

-- %% [markdown]
-- # Images and Carosels
--
-- Here are a collection of widgets that can be used to show screenshots or other images in carosels or tabbed controls.

-- %% [markdown]
-- ## Image Carosel
--
-- An image carosel with dot navigators.

-- %% [markdown]
-- <div style="width:100%; margin:auto; font-family:sans-serif;">
--
--   <div class="mySlides" style="display:none; position:relative;">
--     <img src="https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for slide 1 - replace with your annotation text.</div>
--   </div>
--
--   <div class="mySlides" style="display:none; position:relative;">
--     <img src="https://images.unsplash.com/photo-1470770841072-f978cf4d019e?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for slide 2 - replace with your annotation text.</div>
--   </div>
--
--   <div class="mySlides" style="display:none; position:relative;">
--     <img src="https://images.unsplash.com/photo-1501854140801-50d01698950b?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for slide 3 - replace with your annotation text.</div>
--   </div>
--
--   <div class="mySlides" style="display:none; position:relative;">
--     <img src="https://images.unsplash.com/photo-1464822759023-fed622ff2c3b?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for slide 4 - replace with your annotation text.</div>
--   </div>
--
-- </div>
--
-- <div style="text-align:center; margin-top:10px;">
--   <span class="dot" onclick="currentSlide(1)" style="cursor:pointer; height:15px; width:15px; margin:0 2px; background-color:#bbb; border-radius:50%; display:inline-block;"></span>
--   <span class="dot" onclick="currentSlide(2)" style="cursor:pointer; height:15px; width:15px; margin:0 2px; background-color:#bbb; border-radius:50%; display:inline-block;"></span>
--   <span class="dot" onclick="currentSlide(3)" style="cursor:pointer; height:15px; width:15px; margin:0 2px; background-color:#bbb; border-radius:50%; display:inline-block;"></span>
--   <span class="dot" onclick="currentSlide(4)" style="cursor:pointer; height:15px; width:15px; margin:0 2px; background-color:#bbb; border-radius:50%; display:inline-block;"></span>
-- </div>
--
-- <script>
-- var slideIndex = 1;
-- function currentSlide(n) { showSlides(slideIndex = n); }
-- function showSlides(n) {
--   var slides = document.getElementsByClassName("mySlides");
--   var dots   = document.getElementsByClassName("dot");
--   if (n > slides.length) { slideIndex = 1; }
--   if (n < 1) { slideIndex = slides.length; }
--   for (var i = 0; i < slides.length; i++) { slides[i].style.display = "none"; }
--   for (var i = 0; i < dots.length; i++)   { dots[i].style.backgroundColor = "#bbb"; }
--   slides[slideIndex - 1].style.display = "block";
--   dots[slideIndex - 1].style.backgroundColor = "#717171";
-- }
-- window.onload = function() { showSlides(slideIndex); };
-- </script>

-- %% [markdown]
-- ## Tabbed Images
--
-- An tab control with image items.

-- %% [markdown]
-- <div style="width:100%; margin:auto; font-family:sans-serif;">
--
--   <!-- Tab buttons -->
--   <div style="display:flex; border-bottom:2px solid #e0e0e0; margin-bottom:0;">
--     <button class="dbtab" onclick="showTab(1)" style="padding:10px 18px; border:none; border-bottom:3px solid #1976d2; background:none; font-size:13px; font-weight:bold; color:#1976d2; cursor:pointer; margin-bottom:-2px;">1. Mountains</button>
--     <button class="dbtab" onclick="showTab(2)" style="padding:10px 18px; border:none; border-bottom:3px solid transparent; background:none; font-size:13px; font-weight:bold; color:#888; cursor:pointer; margin-bottom:-2px;">2. Lake</button>
--     <button class="dbtab" onclick="showTab(3)" style="padding:10px 18px; border:none; border-bottom:3px solid transparent; background:none; font-size:13px; font-weight:bold; color:#888; cursor:pointer; margin-bottom:-2px;">3. Forest</button>
--     <button class="dbtab" onclick="showTab(4)" style="padding:10px 18px; border:none; border-bottom:3px solid transparent; background:none; font-size:13px; font-weight:bold; color:#888; cursor:pointer; margin-bottom:-2px;">4. Coast</button>
--   </div>
--
--   <!-- Tab panels -->
--   <div class="dbpanel" style="display:block;">
--     <img src="https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for tab 1 - replace with your annotation text.</div>
--   </div>
--
--   <div class="dbpanel" style="display:none;">
--     <img src="https://images.unsplash.com/photo-1470770841072-f978cf4d019e?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for tab 2 - replace with your annotation text.</div>
--   </div>
--
--   <div class="dbpanel" style="display:none;">
--     <img src="https://images.unsplash.com/photo-1501854140801-50d01698950b?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for tab 3 - replace with your annotation text.</div>
--   </div>
--
--   <div class="dbpanel" style="display:none;">
--     <img src="https://images.unsplash.com/photo-1464822759023-fed622ff2c3b?w=1200&q=80" style="width:100%; height:460px; object-fit:cover; display:block;">
--     <div style="color:#444; font-size:13px; padding:10px 4px;">Caption for tab 4 - replace with your annotation text.</div>
--   </div>
--
-- </div>
--
-- <script>
-- function showTab(n) {
--   var tabs   = document.getElementsByClassName("dbtab");
--   var panels = document.getElementsByClassName("dbpanel");
--   for (var i = 0; i < tabs.length; i++) {
--     tabs[i].style.color = "#888";
--     tabs[i].style.borderBottom = "3px solid transparent";
--     panels[i].style.display = "none";
--   }
--   tabs[n-1].style.color = "#1976d2";
--   tabs[n-1].style.borderBottom = "3px solid #1976d2";
--   panels[n-1].style.display = "block";
-- }
-- window.onload = function() { showTab(1); };
-- </script>

-- %% [markdown]
-- ## PDF Slideshow Viewer
-- Render any publicly hosted PDF as a navigable slide deck directly in a notebook cell, using PDF.js for page-by-page canvas rendering.

-- %% [markdown]
-- <div style="font-family: sans-serif; max-width: 960px; margin: 0 auto; background:#111; border-radius:6px; padding:16px;">
--
--   <div id="pdf-error" style="display:none; color:#f66; text-align:center; padding:20px;"></div>
--   <div id="pdf-loading" style="color:#aaa; text-align:center; padding:40px;">Loading...</div>
--   <canvas id="pdf-canvas" style="display:none; width:100%; border-radius:4px;"></canvas>
--
--   <div style="display:flex; align-items:center; justify-content:center; gap:24px; margin-top:12px;">
--     <button onclick="changePage(-1)"
--       style="background:#333; color:#fff; border:none; border-radius:50%; width:40px; height:40px; font-size:20px; cursor:pointer;">&#8592;</button>
--     <span id="page-info" style="color:#aaa; font-size:14px;">Page 1 of ?</span>
--     <button onclick="changePage(1)"
--       style="background:#333; color:#fff; border:none; border-radius:50%; width:40px; height:40px; font-size:20px; cursor:pointer;">&#8594;</button>
--   </div>
--
-- </div>
--
-- <script src="https://cdnjs.cloudflare.com/ajax/libs/pdf.js/3.11.174/pdf.min.js"></script>
-- <script>
--   // arxiv has open CORS headers - good for testing
--   // swap this for your own PDF once confirmed working
--   const PDF_URL = 'https://arxiv.org/pdf/1706.03762';  // "Attention is All You Need"
--
--   pdfjsLib.GlobalWorkerOptions.workerSrc =
--     'https://cdnjs.cloudflare.com/ajax/libs/pdf.js/3.11.174/pdf.worker.min.js';
--
--   let pdfDoc = null;
--   let currentPage = 1;
--   const canvas = document.getElementById('pdf-canvas');
--   const ctx = canvas.getContext('2d');
--
--   function renderPage(num) {
--     pdfDoc.getPage(num).then(page => {
--       const viewport = page.getViewport({ scale: 1.8 });
--       canvas.height = viewport.height;
--       canvas.width = viewport.width;
--       page.render({ canvasContext: ctx, viewport });
--       document.getElementById('page-info').textContent = 'Page ' + num + ' of ' + pdfDoc.numPages;
--       document.getElementById('pdf-loading').style.display = 'none';
--       canvas.style.display = 'block';
--     });
--   }
--
--   function changePage(delta) {
--     if (!pdfDoc) return;
--     const next = currentPage + delta;
--     if (next < 1 || next > pdfDoc.numPages) return;
--     currentPage = next;
--     renderPage(currentPage);
--   }
--
--   pdfjsLib.getDocument(PDF_URL).promise
--     .then(doc => {
--       pdfDoc = doc;
--       renderPage(1);
--     })
--     .catch(err => {
--       document.getElementById('pdf-loading').style.display = 'none';
--       document.getElementById('pdf-error').style.display = 'block';
--       document.getElementById('pdf-error').textContent = 'Failed to load PDF: ' + err.message;
--     });
-- </script>
