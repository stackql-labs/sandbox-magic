# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; padding: 8px 16px; background: #F8F9FA; border-bottom: 2px solid #E0E0E0; margin: 0; line-height: 1;">
#     <div style="font-size: 14px; color: #666;">
#         <span style="font-weight: bold; color: #333;">Sandbox Magic</span>
#         <span style="margin-left: 8px; color: #999;">|</span>
#         <span style="margin-left: 8px;">Admonitions</span>
#     </div>
#     <div style="display: flex; align-items: center; gap: 8px;">
#         <img src="https://cdn.simpleicons.org/databricks/FF3621" width="24" height="24"/>
#     </div>
# </div>

# %% [markdown]
# # Admonitions
#
# Admonitions are styled callout boxes used to highlight important information. This notebook demonstrates different types of admonitions for use in Databricks notebooks.

# %% [markdown]
# ## Info Box (Blue)
#
# Use for general information, tips, or additional context.
#
# <div style="border-left: 4px solid #1976d2; background: #e3f2fd; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">ℹ️</span>
#         <div>
#             <strong style="color: #0d47a1; font-size: 1.1em;">Information</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is an informational message. Use this style to provide additional context or helpful tips to the reader.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#1976d2` | Background `#e3f2fd` | Title `#0d47a1`

# %% [markdown]
# ## Note Box (Purple)
#
# Use for notes or remarks that should stand out.
#
# <div style="border-left: 4px solid #7b1fa2; background: #f3e5f5; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">📝</span>
#         <div>
#             <strong style="color: #4a148c; font-size: 1.1em;">Note</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a note. Use this style to highlight important remarks or observations that the reader should keep in mind.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#7b1fa2` | Background `#f3e5f5` | Title `#4a148c`

# %% [markdown]
# ## Warning Box (Orange)
#
# Use for warnings or important cautions.
#
# <div style="border-left: 4px solid #ff9800; background: #fff3e0; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">⚠️</span>
#         <div>
#             <strong style="color: #e65100; font-size: 1.1em;">Warning</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a warning message. Use this style to alert readers about potential issues or important cautions they should be aware of.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#ff9800` | Background `#fff3e0` | Title `#e65100`

# %% [markdown]
# ## Error Box (Red)
#
# Use for errors, critical issues, or things to avoid.
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">❌</span>
#         <div>
#             <strong style="color: #c62828; font-size: 1.1em;">Error</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is an error message. Use this style to highlight critical issues, errors, or anti-patterns that should be avoided.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#f44336` | Background `#ffebee` | Title `#c62828`

# %% [markdown]
# ## Success Box (Green)
#
# Use for success messages, best practices, or confirmations.
#
# <div style="border-left: 4px solid #4caf50; background: #e8f5e9; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">✅</span>
#         <div>
#             <strong style="color: #2e7d32; font-size: 1.1em;">Success</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a success message. Use this style for confirmations, best practices, or to indicate something is working correctly.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#4caf50` | Background `#e8f5e9` | Title `#2e7d32`

# %% [markdown]
# ## Tip Box (Teal)
#
# Use for tips, pro-tips, or helpful suggestions.
#
# <div style="border-left: 4px solid #009688; background: #e0f2f1; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">💡</span>
#         <div>
#             <strong style="color: #00695c; font-size: 1.1em;">Tip</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a tip. Use this style for helpful suggestions, pro-tips, or recommendations that can improve the reader's experience.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#009688` | Background `#e0f2f1` | Title `#00695c`

# %% [markdown]
# ## Configuration Box (Grey)
#
# Use for configuration settings or technical details.
#
# <div style="border-left: 4px solid #607d8b; background: #eceff1; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">⚙️</span>
#         <div>
#             <strong style="color: #37474f; font-size: 1.1em;">Configuration</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a configuration message. Use this style for technical settings, configuration options, or system requirements.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#607d8b` | Background `#eceff1` | Title `#37474f`

# %% [markdown]
# ## Goal/Target Box (Amber)
#
# Use for objectives, goals, or targets.
#
# <div style="border-left: 4px solid #ffc107; background: #fffde7; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">🎯</span>
#         <div>
#             <strong style="color: #ff8f00; font-size: 1.1em;">Goal</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This is a goal/target message. Use this style to highlight objectives, targets, or key outcomes that should be achieved.</p>
#         </div>
#     </div>
# </div>
#
# **Colors:** Border `#ffc107` | Background `#fffde7` | Title `#ff8f00`

# %% [markdown]
# ## All Admonition Types - Quick Reference
#
# | Type | Border | Background | Title | Icon |
# |------|--------|------------|-------|------|
# | **Info** | `#1976d2` | `#e3f2fd` | `#0d47a1` | ℹ️ |
# | **Note** | `#7b1fa2` | `#f3e5f5` | `#4a148c` | 📝 |
# | **Warning** | `#ff9800` | `#fff3e0` | `#e65100` | ⚠️ |
# | **Error** | `#f44336` | `#ffebee` | `#c62828` | ❌ |
# | **Success** | `#4caf50` | `#e8f5e9` | `#2e7d32` | ✅ |
# | **Tip** | `#009688` | `#e0f2f1` | `#00695c` | 💡 |
# | **Config** | `#607d8b` | `#eceff1` | `#37474f` | ⚙️ |
# | **Goal** | `#ffc107` | `#fffde7` | `#ff8f00` | 🎯 |

# %% [markdown]
# ## Template Code
#
# Copy and paste this template, then customize:
#
# ```html
# <div style="border-left: 4px solid #BORDER; background: #BACKGROUND; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">EMOJI</span>
#         <div>
#             <strong style="color: #TITLE; font-size: 1.1em;">Title</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">Your message here.</p>
#         </div>
#     </div>
# </div>
# ```

# %% [markdown]
# <div style="display:flex;gap:16px;margin:24px 0">
#   <a href="$./icons" style="flex:1;border:1px solid #e0e0e0;border-radius:8px;padding:16px 20px;text-decoration:none">
#     <span style="display:block;font-size:12px;color:#666;margin-bottom:4px">Previous</span>
#     <span style="display:block;font-size:16px;font-weight:600;color:#1a5276">« Icons</span>
#   </a>
#   <a href="$./codeblocks" style="flex:1;border:1px solid #e0e0e0;border-radius:8px;padding:16px 20px;text-decoration:none;text-align:right">
#     <span style="display:block;font-size:12px;color:#666;margin-bottom:4px">Next</span>
#     <span style="display:block;font-size:16px;font-weight:600;color:#1a5276">Code Blocks »</span>
#   </a>
# </div>

# %% [markdown]
# &copy; 2025 Sandbox Magic. All rights reserved.
