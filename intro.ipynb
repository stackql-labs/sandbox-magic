# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; padding: 8px 16px; background: #F8F9FA; border-bottom: 2px solid #E0E0E0; margin: 0; line-height: 1;">
#     <div style="font-size: 14px; color: #666;">
#         <span style="font-weight: bold; color: #333;">Sandbox Magic</span>
#         <span style="margin-left: 8px; color: #999;">|</span>
#         <span style="margin-left: 8px;">Diagrams as Code</span>
#     </div>
#     <div style="display: flex; align-items: center; gap: 8px;">
#         <img src="https://cdn.simpleicons.org/databricks/FF3621" width="24" height="24"/>
#     </div>
# </div>

# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://www.svgrepo.com/show/354597/wand.svg" alt="Sandbox Magic" width="100" height="100">
#   <h1 style="margin-top: 16px;">Sandbox Magic</h1>
#   <p style="color: #666; font-size: 1.2em;">Diagrams as Code for Databricks Notebooks</p>
# </div>

# %% [markdown]
# ## Overview
#
# Welcome to **Sandbox Magic** - a collection of techniques, patterns, and examples for creating rich, interactive content in Databricks notebooks using **Diagrams as Code** principles.
#
# ### What is Diagrams as Code?
#
# **Diagrams as Code** is an approach where diagrams, visualizations, and rich content are defined using text-based markup languages rather than graphical tools. This approach offers several advantages:
#
# - **Version Control**: Diagrams can be tracked in git alongside your code
# - **Consistency**: Standardized styling and layouts across all documentation
# - **Maintainability**: Easy to update and modify without specialized tools
# - **Collaboration**: Review and iterate on diagrams using standard code review processes
# - **Reproducibility**: Diagrams are always generated from source, eliminating stale or orphaned image files

# %% [markdown]
# <div style="border-left: 4px solid #1976d2; background: #e3f2fd; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
#     <div style="display: flex; align-items: flex-start; gap: 12px;">
#         <span style="font-size: 24px;">ℹ️</span>
#         <div>
#             <strong style="color: #0d47a1; font-size: 1.1em;">About This Repository</strong>
#             <p style="margin: 8px 0 0 0; color: #333;">This repository showcases various techniques for creating rich content in Databricks notebooks, including icons, admonitions, code blocks, Mermaid diagrams, PlantUML diagrams, and C4 architecture diagrams.</p>
#         </div>
#     </div>
# </div>

# %% [markdown]
# ## Notebooks in This Repository
#
# | Notebook | Description |
# |----------|-------------|
# | **[Icons]($./icons)** | Vendor icons and how to use them (AWS, Azure, Databricks, Snowflake, etc.) |
# | **[Admonitions]($./admonitions)** | Info boxes, warnings, notes, and other callouts |
# | **[Code Blocks]($./codeblocks)** | Styled code blocks with syntax highlighting |
# | **[Mermaid]($./mermaid)** | Mermaid diagrams - flowcharts, sequences, and more |
# | **[PlantUML]($./plantuml)** | PlantUML diagrams for UML and architecture |
# | **[C4 PlantUML]($./c4_plantuml)** | C4 architecture diagrams using PlantUML |

# %% [markdown]
# ## Key Technologies
#
# <div style="display: flex; gap: 24px; flex-wrap: wrap; margin: 24px 0;">
#     <div style="text-align: center;">
#         <img src="https://cdn.simpleicons.org/mermaid/FF3670" width="48" height="48"/>
#         <p style="margin-top: 8px; font-weight: bold;">Mermaid</p>
#     </div>
#     <div style="text-align: center;">
#         <img src="https://www.plantuml.com/favicon.ico" width="48" height="48"/>
#         <p style="margin-top: 8px; font-weight: bold;">PlantUML</p>
#     </div>
#     <div style="text-align: center;">
#         <img src="https://cdn.simpleicons.org/simpleicons/111111" width="48" height="48"/>
#         <p style="margin-top: 8px; font-weight: bold;">Simple Icons</p>
#     </div>
#     <div style="text-align: center;">
#         <img src="https://prismjs.com/assets/logo.svg" width="48" height="48"/>
#         <p style="margin-top: 8px; font-weight: bold;">Prism.js</p>
#     </div>
# </div>

# %% [markdown]
# <div style="display:flex;gap:16px;margin:24px 0">
#   <div style="flex:1"></div>
#   <a href="$./icons" style="flex:1;border:1px solid #e0e0e0;border-radius:8px;padding:16px 20px;text-decoration:none;text-align:right">
#     <span style="display:block;font-size:12px;color:#666;margin-bottom:4px">Next</span>
#     <span style="display:block;font-size:16px;font-weight:600;color:#1a5276">Icons »</span>
#   </a>
# </div>

# %% [markdown]
# &copy; 2025 Sandbox Magic. All rights reserved.<br/><br/>Built with <a href="https://mermaid.js.org/" target="_blank">Mermaid</a> | <a href="https://plantuml.com/" target="_blank">PlantUML</a> | <a href="https://simpleicons.org/" target="_blank">Simple Icons</a>
